# %%
import pandas as pd
import random

# %%
data_df = pd.read_csv('log.csv')

# %%
data_df.drop(columns=['comment'], inplace=True)

# %%
data_df['delay'] = data_df['delay'].apply(lambda x: random.randint(0, 10))

# %%
data_df.head()
# Out:
#         id time_stamp   latitude  longitude  course    speed   altitude  \
# 0  Rider-1   14:57:40  52.056000   7.582667   262.0  211.128  1833.3720
# 1  Rider-2   14:57:42  52.056000   7.581833   262.0  212.980  1837.3344
# 2  Rider-3   14:57:42  52.055833   7.581000   262.0  212.980  1840.3824
# 3  Rider-4   14:57:43  52.055833   7.580000   262.0  214.832  1844.3448
# 4  Rider-5   14:57:44  52.055667   7.579167   262.0  214.832  1847.0880
#
#           time_received  delay
# 0  2025-Jun-09 12:36:14      4
# 1  2025-Jun-09 12:36:14      9
# 2  2025-Jun-09 12:36:14     10
# 3  2025-Jun-09 12:36:14     10
# 4  2025-Jun-09 12:36:15      4

# %%
data_df.to_json('data.json', orient='records')
